# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_excel("../data/Survey_Response.xlsx")

# First 5 rows
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Timestamp              17 non-null     str
#  1   Frequency_of_Use       45 non-null     object
#  2   Most_Used_App          13 non-null     str
#  3   Ease_of_Use            50 non-null     int64
#  4   Transaction_Speed      49 non-null     float64
#  5   Network_Dependency     49 non-null     float64
#  6   Service_Charges        49 non-null     float64
#  7   Recommendation Status  50 non-null     object
# dtypes: float64(3), int64(1), object(2), str(2)
# memory usage: 3.3+ KB
