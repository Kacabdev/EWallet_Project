# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("../data/E-Wallet Service Satisfaction and Recommendation Dataset.csv")

# First 5 rows
df.isnull().sum()
# Out:
# App_Category        0
# Frequency_of_Use    2
# Ease_of_Use         1
# Trans_Speed         0
# Net_Dependency      1
# Service_Charges     1
# Recommendation      0
# dtype: int64
